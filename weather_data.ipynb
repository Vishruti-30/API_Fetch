# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # 🔹 Step 1: Install and import the `requests` library
# ## We use the `requests` library to make HTTP requests to the OpenWeatherMap API.

# %%
# !pip install requests --quiet
import requests
import json

# %% [markdown]
# # 🔹 Step 2: Set your API key and base URL
# ## Replace `"your_api_key_here"` with your actual API key.

# %%
API_KEY = "e67aaca4d7b6b99cd907641935e8de56"  # Replace with your OpenWeatherMap API key
BASE_URL = "https://api.openweathermap.org/data/2.5/weather"

# %% [markdown]
# # 🌍 Step 3: Define List of Cities
# ## You can edit this list to include any cities you want to monitor.

# %%
cities = ["Toronto", "New York", "London", "Paris", "Tokyo"]

# %% [markdown]
# # 🔄 Step 4: Fetch Weather Data for Each City
# ## For each city, we'll make a request to the API and extract key information like temperature, description, humidity, and wind speed.

# %%
all_weather_data = {}

for city in cities:
    params = {
        'q': city,
        'appid': API_KEY,
        'units': 'metric'
    }

    response = requests.get(BASE_URL, params=params)
    
    if response.status_code == 200:
        data = response.json()
        all_weather_data[city] = {
            "temperature": data['main']['temp'],
            "description": data['weather'][0]['description'],
            "humidity": data['main']['humidity'],
            "wind_speed": data['wind']['speed']
        }
    else:
        all_weather_data[city] = {
            "error": f"Could not fetch data (status code {response.status_code})"
        }

# %% [markdown]
# # 💾 Step 5: Save Data to JSON File
# ## All weather data will be saved to `weather_data.json` in the current directory.

# %%
with open("weather_data.json", "w") as f:
    json.dump(all_weather_data, f, indent=4)

print("✅ Weather data saved to weather_data.json")
# Out:
# ✅ Weather data saved to weather_data.json
